# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# **Import Linear Regression model implemented**

# %%
from model import Linear_Regression

# %% [markdown]
# Loading the data

# %%
#Loading the data from csv file to a pandas dataframe
salary_data = pd.read_csv('../Linear_Regression/datasets/salary_data.csv')

# %% [markdown]
# Analyzing the data and its distribution

# %%
#printing first five rows
salary_data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
salary_data.tail()
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
#get number of records and features
salary_data.shape
# Out:
# (30, 2)

# %%
#count null values
salary_data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
#separate features and target
X = salary_data.iloc[:,:-1].values
Y = salary_data.iloc[:,1].values

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
Y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872])

# %% [markdown]
# Splitting the dataset into training and test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.33, random_state = 2)

# %% [markdown]
# Training the linear regression model

# %%
model = Linear_Regression(learning_rate=0.02, no_of_iterations=1000)

# %%
model.fit(X_train, Y_train)

# %%
#printing the model parameters
print('weight = ',model.w[0])
print('bias = ', model.b)
# Out:
# weight =  9514.400999035135
# bias =  23697.406507136307

# %% [markdown]
# model/Curve equation
#
# y = wx+b
#
#
# salary = 9.514(experience) + 23697
#
# Model has been trained!

# %% [markdown]
# **Predict the test data**

# %%
test_data_prediction = model.predict(X_test)

# %%
#calculate the loss function
mse = np.mean((test_data_prediction - Y_test)**2)
rmse = np.sqrt(mse)

print("MSE =", mse)
print("RMSE =", rmse)
# Out:
# MSE = 60483757.90524936
# RMSE = 7777.1304415735085

# %% [markdown]
# **Visualizing the predicted values and actual values**

# %%
plt.scatter(X_test,Y_test, color='red')
plt.plot(X_test, test_data_prediction, color='blue')
plt.title('Actual vs Predicted')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
